# %% [markdown]
# baseline ARIMA model

# %% [markdown]
# SARIMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, mean_absolute_error
import warnings
from dateutil.relativedelta import relativedelta

warnings.filterwarnings("ignore")
from pathlib import Path
import os

project_dir = Path(os.getcwd()).parent

# Define the path to the raw data folder relative to the project directory
data_dir = project_dir / 'data' / 'data_files' / 'processed_data'

# Load the data
data = pd.read_csv(data_dir / 'em_imputed_mq_stationary.csv')

# Convert the date column to datetime and set it as the index
data['date'] = pd.to_datetime(data['date'])
data.set_index('date', inplace=True)

# Function to standardize a single column
def z_score(x):
    return (x - x.mean()) / x.std()

normalized = data.copy()

normalized.loc[:, normalized.columns != 'date'] = normalized.loc[:, normalized.columns != 'date'].apply(z_score)

data = normalized

# Select the target variable (GDP)
target_variable = 'China: GDP: Current Prices:PoP GROWTHRATE'

# Check for missing values and handle them if necessary
data[target_variable] = data[target_variable].dropna()

# Split the data into train and test sets
train_data = data[data.index < '2018-06-30'][target_variable].dropna()
test_data = data[data.index >= '2018-06-30'][target_variable].dropna()


# Function to generate artificial testing vintages
def generate_artificial_vintages(data, test_start_date, target_variable):
    test_dates = data[data.index >= test_start_date].index
    vintages = []
    
    for test_date in test_dates:
        train_end_date = test_date - relativedelta(months=1)
        train_data = data[data.index <= train_end_date][target_variable]
        test_value = data.loc[test_date, target_variable]
        vintages.append((train_data, test_date, test_value))
    
    return vintages


# Generate artificial testing vintages
vintages = generate_artificial_vintages(data, '2018-06-30', target_variable)

# Initialize lists to store results
forecasts = []
actuals = []
forecast_dates = []
confidence_intervals = []

# Iterate through vintages
for train_data, test_date, actual_value in vintages:
    # Check for and remove any inf or nan values
    mask = np.isfinite(train_data)
    train_data = train_data[mask]
    
    if len(train_data) == 0:
        print(f"Warning: No valid data for {test_date}")
        continue

    try:
        # Perform ADF test
        result = adfuller(train_data)

        # If the series is not stationary, difference the training data
        if result[1] > 0.05:
            train_data = train_data.diff().dropna()
            d = 1
        else:
            d = 0

        # Define the order (p, d, q) and seasonal order (P, D, Q, s) for SARIMAX model
        p, q = 3, 1
        P, D, Q, s = 1, 0, 1, 4 

        # Fit the SARIMAX model
        sarimax_model = SARIMAX(train_data, 
                                order=(p, d, q), 
                                seasonal_order=(P, D, Q, s))
        sarimax_result = sarimax_model.fit()

        # Forecast for the test date
        forecast = sarimax_result.get_forecast(steps=1)
        mean_forecast = forecast.predicted_mean[0]
        conf_int = forecast.conf_int()
        
        forecasts.append(mean_forecast)
        actuals.append(actual_value)
        forecast_dates.append(test_date)
        confidence_intervals.append(conf_int)
    except Exception as e:
        print(f"Error forecasting for {test_date}: {str(e)}")

# Convert forecasts and actuals to numpy arrays, dropping NaN values
forecasts = np.array(forecasts)
actuals = np.array(actuals)
forecast_dates = pd.to_datetime(forecast_dates)
confidence_intervals = np.array(confidence_intervals).squeeze()

# Drop NaN values from actuals and corresponding forecasts, dates, and confidence intervals
mask = ~np.isnan(actuals)
actuals = actuals[mask]
forecasts = forecasts[mask]
forecast_dates = forecast_dates[mask]
confidence_intervals = confidence_intervals[mask]

# Plot the forecast against actual test data for the test period only
plt.figure(figsize=(10, 6))
plt.plot(test_data.index, test_data, label='Actual Test Data')
plt.plot(forecast_dates, forecasts, label='Forecast')
plt.fill_between(forecast_dates, confidence_intervals[:, 0], confidence_intervals[:, 1], color='gray', alpha=0.2, label='95% Confidence Interval')
plt.title('SARIMA Forecast vs Actual (Test Period)')
plt.legend()
plt.show()

# Evaluate the model on the test data
mse = mean_squared_error(actuals, forecasts)
mae = mean_absolute_error(actuals, forecasts)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((actuals - forecasts) / actuals)) * 100

print(f'MSE: {mse}')
print(f'MAE: {mae}')
print(f'RMSE: {rmse}')
print(f'MAPE: {mape}%')
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.67890D-01    |proj g|=  1.49284D+01
#
# At iterate    5    f=  4.44704D-02    |proj g|=  5.61677D-01
#
# At iterate   10    f= -1.06751D-01    |proj g|=  6.16203D-02
#
# At iterate   15    f= -1.12785D-01    |proj g|=  1.20491D-01
#
# At iterate   20    f= -1.34799D-01    |proj g|=  2.10115D-01
#
# At iterate   25    f= -1.44986D-01    |proj g|=  2.66103D-02
#
# At iterate   30    f= -1.48185D-01    |proj g|=  1.79580D-02
#
# At iterate   35    f= -1.55089D-01    |proj g|=  2.84270D-01
#
# At iterate   40    f= -1.59832D-01    |proj g|=  3.88009D-01
#
# At iterate   45    f= -1.70514D-01    |proj g|=  3.30296D-01
#
# At iterate   50    f= -1.76878D-01    |proj g|=  5.93268D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     70      1     0     0   5.933D-02  -1.769D-01
#   F = -0.17687830797734236
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.49757D-01    |proj g|=  1.48498D+01
#
# At iterate    5    f=  3.40613D-02    |proj g|=  5.71583D-01
#
# At iterate   10    f= -1.18960D-01    |proj g|=  4.44143D-01
#
# At iterate   15    f= -1.24798D-01    |proj g|=  5.59216D-02
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   20    f= -1.47009D-01    |proj g|=  7.19150D-02
#
# At iterate   25    f= -1.52109D-01    |proj g|=  7.64659D-02
#
# At iterate   30    f= -1.55613D-01    |proj g|=  1.03646D-01
#
# At iterate   35    f= -1.60932D-01    |proj g|=  1.57070D-01
#
# At iterate   40    f= -1.76302D-01    |proj g|=  2.08791D-01
#
# At iterate   45    f= -1.81903D-01    |proj g|=  1.34492D-02
#
# At iterate   50    f= -1.83553D-01    |proj g|=  9.52417D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     70      1     0     0   9.524D-03  -1.836D-01
#   F = -0.18355326703289815
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.49757D-01    |proj g|=  1.48498D+01
#
# At iterate    5    f=  3.40613D-02    |proj g|=  5.71583D-01
#
# At iterate   10    f= -1.18960D-01    |proj g|=  4.44143D-01
#
# At iterate   15    f= -1.24798D-01    |proj g|=  5.59216D-02
#
# At iterate   20    f= -1.47009D-01    |proj g|=  7.19150D-02
#
# At iterate   25    f= -1.52109D-01    |proj g|=  7.64659D-02
#
# At iterate   30    f= -1.55613D-01    |proj g|=  1.03646D-01
#
# At iterate   35    f= -1.60932D-01    |proj g|=  1.57070D-01
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   40    f= -1.76302D-01    |proj g|=  2.08791D-01
#
# At iterate   45    f= -1.81903D-01    |proj g|=  1.34492D-02
#
# At iterate   50    f= -1.83553D-01    |proj g|=  9.52417D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     70      1     0     0   9.524D-03  -1.836D-01
#   F = -0.18355326703289815
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.49757D-01    |proj g|=  1.48498D+01
#
# At iterate    5    f=  3.40613D-02    |proj g|=  5.71583D-01
#
# At iterate   10    f= -1.18960D-01    |proj g|=  4.44143D-01
#
# At iterate   15    f= -1.24798D-01    |proj g|=  5.59216D-02
#
# At iterate   20    f= -1.47009D-01    |proj g|=  7.19150D-02
#
# At iterate   25    f= -1.52109D-01    |proj g|=  7.64659D-02
#
# At iterate   30    f= -1.55613D-01    |proj g|=  1.03646D-01
#
# At iterate   35    f= -1.60932D-01    |proj g|=  1.57070D-01
#
# At iterate   40    f= -1.76302D-01    |proj g|=  2.08791D-01
#
# At iterate   45    f= -1.81903D-01    |proj g|=  1.34492D-02
#
# At iterate   50    f= -1.83553D-01    |proj g|=  9.52417D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     70      1     0     0   9.524D-03  -1.836D-01
#   F = -0.18355326703289815
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.47259D-01    |proj g|=  1.49412D+01
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#  This problem is unconstrained.
# At iterate    5    f=  3.73139D-02    |proj g|=  6.18732D-01
#
# At iterate   10    f= -1.01230D-01    |proj g|=  9.59407D-01
#
# At iterate   15    f= -1.24291D-01    |proj g|=  3.53426D-02
#
# At iterate   20    f= -1.35236D-01    |proj g|=  8.06697D-02
#
# At iterate   25    f= -1.53938D-01    |proj g|=  1.01793D-01
#
# At iterate   30    f= -1.61085D-01    |proj g|=  4.12120D-02
#
# At iterate   35    f= -1.78616D-01    |proj g|=  8.10521D-02
#
# At iterate   40    f= -1.79783D-01    |proj g|=  4.23683D-02
#
# At iterate   45    f= -1.89365D-01    |proj g|=  1.93139D-01
#
# At iterate   50    f= -1.93889D-01    |proj g|=  3.33214D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     93      2     0     0   3.332D-02  -1.939D-01
#   F = -0.19388850378020347
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.47259D-01    |proj g|=  1.49412D+01
#
# At iterate    5    f=  3.73139D-02    |proj g|=  6.18732D-01
#
# At iterate   10    f= -1.01230D-01    |proj g|=  9.59407D-01
#
# At iterate   15    f= -1.24291D-01    |proj g|=  3.53426D-02
#
# At iterate   20    f= -1.35236D-01    |proj g|=  8.06697D-02
#
# At iterate   25    f= -1.53938D-01    |proj g|=  1.01793D-01
#
# At iterate   30    f= -1.61085D-01    |proj g|=  4.12120D-02
#
# At iterate   35    f= -1.78616D-01    |proj g|=  8.10521D-02
#
# At iterate   40    f= -1.79783D-01    |proj g|=  4.23683D-02
#
# At iterate   45    f= -1.89365D-01    |proj g|=  1.93139D-01
#
# At iterate   50    f= -1.93889D-01    |proj g|=  3.33214D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     93      2     0     0   3.332D-02  -1.939D-01
#   F = -0.19388850378020347
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.47259D-01    |proj g|=  1.49412D+01
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#  This problem is unconstrained.
# At iterate    5    f=  3.73139D-02    |proj g|=  6.18732D-01
#
# At iterate   10    f= -1.01230D-01    |proj g|=  9.59407D-01
#
# At iterate   15    f= -1.24291D-01    |proj g|=  3.53426D-02
#
# At iterate   20    f= -1.35236D-01    |proj g|=  8.06697D-02
#
# At iterate   25    f= -1.53938D-01    |proj g|=  1.01793D-01
#
# At iterate   30    f= -1.61085D-01    |proj g|=  4.12120D-02
#
# At iterate   35    f= -1.78616D-01    |proj g|=  8.10521D-02
#
# At iterate   40    f= -1.79783D-01    |proj g|=  4.23683D-02
#
# At iterate   45    f= -1.89365D-01    |proj g|=  1.93139D-01
#
# At iterate   50    f= -1.93889D-01    |proj g|=  3.33214D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     93      2     0     0   3.332D-02  -1.939D-01
#   F = -0.19388850378020347
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.34645D-01    |proj g|=  1.49336D+01
#
# At iterate    5    f=  3.34112D-02    |proj g|=  2.92829D-01
#
# At iterate   10    f= -1.23541D-01    |proj g|=  6.08511D-01
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#  This problem is unconstrained.
# At iterate   15    f= -1.31870D-01    |proj g|=  4.08711D-02
#
# At iterate   20    f= -1.45440D-01    |proj g|=  2.33270D-01
#
# At iterate   25    f= -1.60510D-01    |proj g|=  1.39020D-02
#
# At iterate   30    f= -1.63069D-01    |proj g|=  3.94300D-02
#
# At iterate   35    f= -1.66851D-01    |proj g|=  9.22462D-02
#   ys=-2.115E-02  -gs= 1.130E-02 BFGS update SKIPPED
#
# At iterate   40    f= -1.71979D-01    |proj g|=  1.26748D-01
#
# At iterate   45    f= -1.75823D-01    |proj g|=  5.29102D-02
#
# At iterate   50    f= -1.75881D-01    |proj g|=  1.44411D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     93      1     1     0   1.444D-02  -1.759D-01
#   F = -0.17588080634350339
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.34645D-01    |proj g|=  1.49336D+01
#
# At iterate    5    f=  3.34112D-02    |proj g|=  2.92829D-01
#
# At iterate   10    f= -1.23541D-01    |proj g|=  6.08511D-01
#
# At iterate   15    f= -1.31870D-01    |proj g|=  4.08711D-02
#  This problem is unconstrained.
# At iterate   20    f= -1.45440D-01    |proj g|=  2.33270D-01
#
# At iterate   25    f= -1.60510D-01    |proj g|=  1.39020D-02
#
# At iterate   30    f= -1.63069D-01    |proj g|=  3.94300D-02
#
# At iterate   35    f= -1.66851D-01    |proj g|=  9.22462D-02
#   ys=-2.115E-02  -gs= 1.130E-02 BFGS update SKIPPED
#
# At iterate   40    f= -1.71979D-01    |proj g|=  1.26748D-01
#
# At iterate   45    f= -1.75823D-01    |proj g|=  5.29102D-02
#
# At iterate   50    f= -1.75881D-01    |proj g|=  1.44411D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     93      1     1     0   1.444D-02  -1.759D-01
#   F = -0.17588080634350339
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.34645D-01    |proj g|=  1.49336D+01
#
# At iterate    5    f=  3.34112D-02    |proj g|=  2.92829D-01
#
# At iterate   10    f= -1.23541D-01    |proj g|=  6.08511D-01
#
# At iterate   15    f= -1.31870D-01    |proj g|=  4.08711D-02
#
# At iterate   20    f= -1.45440D-01    |proj g|=  2.33270D-01
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   25    f= -1.60510D-01    |proj g|=  1.39020D-02
#
# At iterate   30    f= -1.63069D-01    |proj g|=  3.94300D-02
#
# At iterate   35    f= -1.66851D-01    |proj g|=  9.22462D-02
#   ys=-2.115E-02  -gs= 1.130E-02 BFGS update SKIPPED
#
# At iterate   40    f= -1.71979D-01    |proj g|=  1.26748D-01
#
# At iterate   45    f= -1.75823D-01    |proj g|=  5.29102D-02
#
# At iterate   50    f= -1.75881D-01    |proj g|=  1.44411D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     93      1     1     0   1.444D-02  -1.759D-01
#   F = -0.17588080634350339
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.34645D-01    |proj g|=  1.49336D+01
#
# At iterate    5    f=  3.34112D-02    |proj g|=  2.92829D-01
#
# At iterate   10    f= -1.23541D-01    |proj g|=  6.08511D-01
#
# At iterate   15    f= -1.31870D-01    |proj g|=  4.08711D-02
#
# At iterate   20    f= -1.45440D-01    |proj g|=  2.33270D-01
#
# At iterate   25    f= -1.60510D-01    |proj g|=  1.39020D-02
#
# At iterate   30    f= -1.63069D-01    |proj g|=  3.94300D-02
#
# At iterate   35    f= -1.66851D-01    |proj g|=  9.22462D-02
#   ys=-2.115E-02  -gs= 1.130E-02 BFGS update SKIPPED
#
# At iterate   40    f= -1.71979D-01    |proj g|=  1.26748D-01
#
# At iterate   45    f= -1.75823D-01    |proj g|=  5.29102D-02
#
# At iterate   50    f= -1.75881D-01    |proj g|=  1.44411D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     93      1     1     0   1.444D-02  -1.759D-01
#   F = -0.17588080634350339
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.32408D-01    |proj g|=  1.47493D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      3     13      1     0     0   1.287D+00   1.198D-01
#   F =  0.11984191081464492
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.32408D-01    |proj g|=  1.47493D+01
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7      3     13      1     0     0   1.287D+00   1.198D-01
#   F =  0.11984191081464492
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.99893D-01    |proj g|=  1.39781D+01
#
# At iterate    5    f= -1.21107D-02    |proj g|=  2.02983D-01
#
# At iterate   10    f= -1.36768D-01    |proj g|=  4.42229D-02
#
# At iterate   15    f= -1.48578D-01    |proj g|=  2.72750D-01
#
# At iterate   20    f= -1.65688D-01    |proj g|=  1.75786D-01
#
# At iterate   25    f= -1.67772D-01    |proj g|=  1.13558D-01
#
# At iterate   30    f= -1.70699D-01    |proj g|=  8.79466D-02
#
# At iterate   35    f= -1.75432D-01    |proj g|=  7.10584D-02
#
# At iterate   40    f= -1.95268D-01    |proj g|=  4.53397D-01
#
# At iterate   45    f= -1.99450D-01    |proj g|=  4.02506D-02
#
# At iterate   50    f= -2.00881D-01    |proj g|=  2.12367D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     74      1     0     0   2.124D-02  -2.009D-01
#   F = -0.20088074592977134
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.99893D-01    |proj g|=  1.39781D+01
#
# At iterate    5    f= -1.21107D-02    |proj g|=  2.02983D-01
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   10    f= -1.36768D-01    |proj g|=  4.42229D-02
#
# At iterate   15    f= -1.48578D-01    |proj g|=  2.72750D-01
#
# At iterate   20    f= -1.65688D-01    |proj g|=  1.75786D-01
#
# At iterate   25    f= -1.67772D-01    |proj g|=  1.13558D-01
#
# At iterate   30    f= -1.70699D-01    |proj g|=  8.79466D-02
#
# At iterate   35    f= -1.75432D-01    |proj g|=  7.10584D-02
#
# At iterate   40    f= -1.95268D-01    |proj g|=  4.53397D-01
#
# At iterate   45    f= -1.99450D-01    |proj g|=  4.02506D-02
#
# At iterate   50    f= -2.00881D-01    |proj g|=  2.12367D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     74      1     0     0   2.124D-02  -2.009D-01
#   F = -0.20088074592977134
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.99893D-01    |proj g|=  1.39781D+01
#
# At iterate    5    f= -1.21107D-02    |proj g|=  2.02983D-01
#
# At iterate   10    f= -1.36768D-01    |proj g|=  4.42229D-02
#
# At iterate   15    f= -1.48578D-01    |proj g|=  2.72750D-01
#
# At iterate   20    f= -1.65688D-01    |proj g|=  1.75786D-01
#
# At iterate   25    f= -1.67772D-01    |proj g|=  1.13558D-01
#
# At iterate   30    f= -1.70699D-01    |proj g|=  8.79466D-02
#
# At iterate   35    f= -1.75432D-01    |proj g|=  7.10584D-02
#
# At iterate   40    f= -1.95268D-01    |proj g|=  4.53397D-01
#
# At iterate   45    f= -1.99450D-01    |proj g|=  4.02506D-02
#
# At iterate   50    f= -2.00881D-01    |proj g|=  2.12367D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     74      1     0     0   2.124D-02  -2.009D-01
#   F = -0.20088074592977134
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.05091D-01    |proj g|=  1.41101D+01
#
# At iterate    5    f=  1.80520D-02    |proj g|=  7.50051D-01
#
# At iterate   10    f= -1.41280D-01    |proj g|=  1.05387D-01
#
# At iterate   15    f= -1.49544D-01    |proj g|=  2.61606D-01
#
# At iterate   20    f= -1.71885D-01    |proj g|=  8.22143D-02
#
# At iterate   25    f= -1.75424D-01    |proj g|=  4.03455D-02
#
# At iterate   30    f= -1.78684D-01    |proj g|=  5.81457D-02
#
# At iterate   35    f= -1.83983D-01    |proj g|=  8.08786D-02
#
# At iterate   40    f= -1.97882D-01    |proj g|=  1.15850D-01
#
# At iterate   45    f= -2.01588D-01    |proj g|=  1.30508D-02
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   50    f= -2.02530D-01    |proj g|=  5.88841D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     74      1     0     0   5.888D-02  -2.025D-01
#   F = -0.20252991588620314
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.05091D-01    |proj g|=  1.41101D+01
#
# At iterate    5    f=  1.80520D-02    |proj g|=  7.50051D-01
#
# At iterate   10    f= -1.41280D-01    |proj g|=  1.05387D-01
#
# At iterate   15    f= -1.49544D-01    |proj g|=  2.61606D-01
#
# At iterate   20    f= -1.71885D-01    |proj g|=  8.22143D-02
#
# At iterate   25    f= -1.75424D-01    |proj g|=  4.03455D-02
#
# At iterate   30    f= -1.78684D-01    |proj g|=  5.81457D-02
#
# At iterate   35    f= -1.83983D-01    |proj g|=  8.08786D-02
#
# At iterate   40    f= -1.97882D-01    |proj g|=  1.15850D-01
#
# At iterate   45    f= -2.01588D-01    |proj g|=  1.30508D-02
#
# At iterate   50    f= -2.02530D-01    |proj g|=  5.88841D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     74      1     0     0   5.888D-02  -2.025D-01
#   F = -0.20252991588620314
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.05091D-01    |proj g|=  1.41101D+01
#
# At iterate    5    f=  1.80520D-02    |proj g|=  7.50051D-01
#
# At iterate   10    f= -1.41280D-01    |proj g|=  1.05387D-01
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   15    f= -1.49544D-01    |proj g|=  2.61606D-01
#
# At iterate   20    f= -1.71885D-01    |proj g|=  8.22143D-02
#
# At iterate   25    f= -1.75424D-01    |proj g|=  4.03455D-02
#
# At iterate   30    f= -1.78684D-01    |proj g|=  5.81457D-02
#
# At iterate   35    f= -1.83983D-01    |proj g|=  8.08786D-02
#
# At iterate   40    f= -1.97882D-01    |proj g|=  1.15850D-01
#
# At iterate   45    f= -2.01588D-01    |proj g|=  1.30508D-02
#
# At iterate   50    f= -2.02530D-01    |proj g|=  5.88841D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     74      1     0     0   5.888D-02  -2.025D-01
#   F = -0.20252991588620314
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.94043D-01    |proj g|=  1.41108D+01
#
# At iterate    5    f=  1.18554D-02    |proj g|=  7.05742D-01
#
# At iterate   10    f= -1.49908D-01    |proj g|=  3.23139D-02
#
# At iterate   15    f= -1.60446D-01    |proj g|=  2.63192D-01
#
# At iterate   20    f= -1.77429D-01    |proj g|=  6.87614D-02
#
# At iterate   25    f= -1.80023D-01    |proj g|=  2.23791D-02
#
# At iterate   30    f= -1.83810D-01    |proj g|=  4.20360D-02
#
# At iterate   35    f= -1.90933D-01    |proj g|=  3.69991D-02
#
# At iterate   40    f= -2.00902D-01    |proj g|=  1.53625D-01
#
# At iterate   45    f= -2.05227D-01    |proj g|=  4.20118D-03
#
# At iterate   50    f= -2.06297D-01    |proj g|=  1.12709D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     71      1     0     0   1.127D-01  -2.063D-01
#   F = -0.20629651869680102
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.94043D-01    |proj g|=  1.41108D+01
#
# At iterate    5    f=  1.18554D-02    |proj g|=  7.05742D-01
#
# At iterate   10    f= -1.49908D-01    |proj g|=  3.23139D-02
#
# At iterate   15    f= -1.60446D-01    |proj g|=  2.63192D-01
#
# At iterate   20    f= -1.77429D-01    |proj g|=  6.87614D-02
#
# At iterate   25    f= -1.80023D-01    |proj g|=  2.23791D-02
#
# At iterate   30    f= -1.83810D-01    |proj g|=  4.20360D-02
#
# At iterate   35    f= -1.90933D-01    |proj g|=  3.69991D-02
#
# At iterate   40    f= -2.00902D-01    |proj g|=  1.53625D-01
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   45    f= -2.05227D-01    |proj g|=  4.20118D-03
#
# At iterate   50    f= -2.06297D-01    |proj g|=  1.12709D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     71      1     0     0   1.127D-01  -2.063D-01
#   F = -0.20629651869680102
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.94043D-01    |proj g|=  1.41108D+01
#
# At iterate    5    f=  1.18554D-02    |proj g|=  7.05742D-01
#
# At iterate   10    f= -1.49908D-01    |proj g|=  3.23139D-02
#
# At iterate   15    f= -1.60446D-01    |proj g|=  2.63192D-01
#
# At iterate   20    f= -1.77429D-01    |proj g|=  6.87614D-02
#
# At iterate   25    f= -1.80023D-01    |proj g|=  2.23791D-02
#
# At iterate   30    f= -1.83810D-01    |proj g|=  4.20360D-02
#
# At iterate   35    f= -1.90933D-01    |proj g|=  3.69991D-02
#
# At iterate   40    f= -2.00902D-01    |proj g|=  1.53625D-01
#
# At iterate   45    f= -2.05227D-01    |proj g|=  4.20118D-03
#
# At iterate   50    f= -2.06297D-01    |proj g|=  1.12709D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     71      1     0     0   1.127D-01  -2.063D-01
#   F = -0.20629651869680102
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.94043D-01    |proj g|=  1.41108D+01
#
# At iterate    5    f=  1.18554D-02    |proj g|=  7.05742D-01
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   10    f= -1.49908D-01    |proj g|=  3.23139D-02
#
# At iterate   15    f= -1.60446D-01    |proj g|=  2.63192D-01
#
# At iterate   20    f= -1.77429D-01    |proj g|=  6.87614D-02
#
# At iterate   25    f= -1.80023D-01    |proj g|=  2.23791D-02
#
# At iterate   30    f= -1.83810D-01    |proj g|=  4.20360D-02
#
# At iterate   35    f= -1.90933D-01    |proj g|=  3.69991D-02
#
# At iterate   40    f= -2.00902D-01    |proj g|=  1.53625D-01
#
# At iterate   45    f= -2.05227D-01    |proj g|=  4.20118D-03
#
# At iterate   50    f= -2.06297D-01    |proj g|=  1.12709D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     71      1     0     0   1.127D-01  -2.063D-01
#   F = -0.20629651869680102
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.39661D-01    |proj g|=  7.28485D+00
#
# At iterate    5    f=  4.10424D-02    |proj g|=  4.40312D-01
#
# At iterate   10    f= -4.88529D-02    |proj g|=  1.31662D-01
#
# At iterate   15    f= -5.59948D-02    |proj g|=  6.71439D-02
#
# At iterate   20    f= -7.31751D-02    |proj g|=  1.13871D-01
#
# At iterate   25    f= -7.82571D-02    |proj g|=  1.90219D-02
#
# At iterate   30    f= -8.22887D-02    |proj g|=  7.86949D-02
#
# At iterate   35    f= -8.60771D-02    |proj g|=  5.40862D-01
#
# At iterate   40    f= -9.82468D-02    |proj g|=  7.73922D-02
#
# At iterate   45    f= -1.00856D-01    |proj g|=  7.68767D-03
#
# At iterate   50    f= -1.05025D-01    |proj g|=  1.03520D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     68      1     0     0   1.035D-02  -1.050D-01
#   F = -0.10502533901827306
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.39661D-01    |proj g|=  7.28485D+00
#
# At iterate    5    f=  4.10424D-02    |proj g|=  4.40312D-01
#
# At iterate   10    f= -4.88529D-02    |proj g|=  1.31662D-01
#
# At iterate   15    f= -5.59948D-02    |proj g|=  6.71439D-02
#
# At iterate   20    f= -7.31751D-02    |proj g|=  1.13871D-01
#
# At iterate   25    f= -7.82571D-02    |proj g|=  1.90219D-02
#
# At iterate   30    f= -8.22887D-02    |proj g|=  7.86949D-02
#
# At iterate   35    f= -8.60771D-02    |proj g|=  5.40862D-01
#
# At iterate   40    f= -9.82468D-02    |proj g|=  7.73922D-02
#
# At iterate   45    f= -1.00856D-01    |proj g|=  7.68767D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   50    f= -1.05025D-01    |proj g|=  1.03520D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     68      1     0     0   1.035D-02  -1.050D-01
#   F = -0.10502533901827306
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.33983D+00    |proj g|=  6.46037D+01
#
# At iterate    5    f=  1.78865D-01    |proj g|=  2.12335D-01
#
# At iterate   10    f=  1.38448D-01    |proj g|=  1.08258D+00
#
# At iterate   15    f=  2.71630D-02    |proj g|=  1.95900D-01
#
# At iterate   20    f=  8.21504D-03    |proj g|=  2.08947D-01
#
# At iterate   25    f= -5.93580D-03    |proj g|=  1.68290D-01
#
# At iterate   30    f= -9.15115D-03    |proj g|=  1.14557D-02
#
# At iterate   35    f= -9.21098D-03    |proj g|=  8.38740D-03
#
# At iterate   40    f= -9.27469D-03    |proj g|=  5.24109D-02
#
# At iterate   45    f= -9.69449D-03    |proj g|=  1.97298D-02
#
# At iterate   50    f= -9.71687D-03    |proj g|=  4.07995D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     70      1     0     0   4.080D-03  -9.717D-03
#   F =  -9.7168657771793746E-003
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.33983D+00    |proj g|=  6.46037D+01
#
# At iterate    5    f=  1.78865D-01    |proj g|=  2.12335D-01
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   10    f=  1.38448D-01    |proj g|=  1.08258D+00
#
# At iterate   15    f=  2.71630D-02    |proj g|=  1.95900D-01
#
# At iterate   20    f=  8.21504D-03    |proj g|=  2.08947D-01
#
# At iterate   25    f= -5.93580D-03    |proj g|=  1.68290D-01
#
# At iterate   30    f= -9.15115D-03    |proj g|=  1.14557D-02
#
# At iterate   35    f= -9.21098D-03    |proj g|=  8.38740D-03
#
# At iterate   40    f= -9.27469D-03    |proj g|=  5.24109D-02
#
# At iterate   45    f= -9.69449D-03    |proj g|=  1.97298D-02
#
# At iterate   50    f= -9.71687D-03    |proj g|=  4.07995D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     70      1     0     0   4.080D-03  -9.717D-03
#   F =  -9.7168657771793746E-003
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.33983D+00    |proj g|=  6.46037D+01
#
# At iterate    5    f=  1.78865D-01    |proj g|=  2.12335D-01
#
# At iterate   10    f=  1.38448D-01    |proj g|=  1.08258D+00
#
# At iterate   15    f=  2.71630D-02    |proj g|=  1.95900D-01
#
# At iterate   20    f=  8.21504D-03    |proj g|=  2.08947D-01
#
# At iterate   25    f= -5.93580D-03    |proj g|=  1.68290D-01
#
# At iterate   30    f= -9.15115D-03    |proj g|=  1.14557D-02
#
# At iterate   35    f= -9.21098D-03    |proj g|=  8.38740D-03
#
# At iterate   40    f= -9.27469D-03    |proj g|=  5.24109D-02
#
# At iterate   45    f= -9.69449D-03    |proj g|=  1.97298D-02
#
# At iterate   50    f= -9.71687D-03    |proj g|=  4.07995D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     70      1     0     0   4.080D-03  -9.717D-03
#   F =  -9.7168657771793746E-003
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.57330D-01    |proj g|=  7.09811D-01
#
# At iterate    5    f=  2.08494D-03    |proj g|=  6.76410D-02
#
# At iterate   10    f= -1.35478D-02    |proj g|=  3.19132D-02
#
# At iterate   15    f= -1.39884D-02    |proj g|=  1.40809D-03
#
# At iterate   20    f= -1.46990D-02    |proj g|=  2.00888D-02
#
# At iterate   25    f= -1.95159D-02    |proj g|=  1.29375D-02
#
# At iterate   30    f= -2.20185D-02    |proj g|=  9.51551D-03
#
# At iterate   35    f= -3.91286D-02    |proj g|=  2.22706D-01
#
# At iterate   40    f= -4.14435D-02    |proj g|=  3.87897D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   45    f= -4.50642D-02    |proj g|=  1.51995D-01
#
# At iterate   50    f= -4.82178D-02    |proj g|=  1.42509D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     79      1     0     0   1.425D-02  -4.822D-02
#   F =  -4.8217798701177428E-002
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.57330D-01    |proj g|=  7.09811D-01
#
# At iterate    5    f=  2.08494D-03    |proj g|=  6.76410D-02
#
# At iterate   10    f= -1.35478D-02    |proj g|=  3.19132D-02
#
# At iterate   15    f= -1.39884D-02    |proj g|=  1.40809D-03
#
# At iterate   20    f= -1.46990D-02    |proj g|=  2.00888D-02
#
# At iterate   25    f= -1.95159D-02    |proj g|=  1.29375D-02
#
# At iterate   30    f= -2.20185D-02    |proj g|=  9.51551D-03
#
# At iterate   35    f= -3.91286D-02    |proj g|=  2.22706D-01
#
# At iterate   40    f= -4.14435D-02    |proj g|=  3.87897D-03
#
# At iterate   45    f= -4.50642D-02    |proj g|=  1.51995D-01
#
# At iterate   50    f= -4.82178D-02    |proj g|=  1.42509D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     79      1     0     0   1.425D-02  -4.822D-02
#   F =  -4.8217798701177428E-002
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.57330D-01    |proj g|=  7.09811D-01
#
# At iterate    5    f=  2.08494D-03    |proj g|=  6.76410D-02
#
# At iterate   10    f= -1.35478D-02    |proj g|=  3.19132D-02
#
# At iterate   15    f= -1.39884D-02    |proj g|=  1.40809D-03
#
# At iterate   20    f= -1.46990D-02    |proj g|=  2.00888D-02
#
# At iterate   25    f= -1.95159D-02    |proj g|=  1.29375D-02
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   30    f= -2.20185D-02    |proj g|=  9.51551D-03
#
# At iterate   35    f= -3.91286D-02    |proj g|=  2.22706D-01
#
# At iterate   40    f= -4.14435D-02    |proj g|=  3.87897D-03
#
# At iterate   45    f= -4.50642D-02    |proj g|=  1.51995D-01
#
# At iterate   50    f= -4.82178D-02    |proj g|=  1.42509D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     79      1     0     0   1.425D-02  -4.822D-02
#   F =  -4.8217798701177428E-002
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.82476D-01    |proj g|=  7.05944D-01
#
# At iterate    5    f=  3.50224D-02    |proj g|=  5.13460D-01
#
# At iterate   10    f=  1.56540D-02    |proj g|=  4.47339D-02
#
# At iterate   15    f=  1.25566D-02    |proj g|=  3.59014D-03
#
# At iterate   20    f=  1.25515D-02    |proj g|=  1.31892D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     22     39      1     0     0   1.633D-03   1.255D-02
#   F =   1.2551478972357472E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.82476D-01    |proj g|=  7.05944D-01
#
# At iterate    5    f=  3.50224D-02    |proj g|=  5.13460D-01
#
# At iterate   10    f=  1.56540D-02    |proj g|=  4.47339D-02
#
# At iterate   15    f=  1.25566D-02    |proj g|=  3.59014D-03
#
# At iterate   20    f=  1.25515D-02    |proj g|=  1.31892D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     22     39      1     0     0   1.633D-03   1.255D-02
#   F =   1.2551478972357472E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.82476D-01    |proj g|=  7.05944D-01
#
# At iterate    5    f=  3.50224D-02    |proj g|=  5.13460D-01
#
# At iterate   10    f=  1.56540D-02    |proj g|=  4.47339D-02
#
# At iterate   15    f=  1.25566D-02    |proj g|=  3.59014D-03
#
# At iterate   20    f=  1.25515D-02    |proj g|=  1.31892D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     22     39      1     0     0   1.633D-03   1.255D-02
#   F =   1.2551478972357472E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.82476D-01    |proj g|=  7.05944D-01
#
# ...
#
# At iterate   15    f=  5.37869D-03    |proj g|=  1.64646D-03
#
# At iterate   20    f=  5.26695D-03    |proj g|=  6.08476D-03
#
# At iterate   25    f=  4.93395D-03    |proj g|=  3.26046D-04
#
# At iterate   30    f=  4.93354D-03    |proj g|=  5.19079D-04
#
# At iterate   35    f=  4.93196D-03    |proj g|=  3.03728D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     39     52      1     0     0   8.233D-05   4.931D-03
#   F =   4.9313750089807866E-003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.75855D-01    |proj g|=  8.43939D-01
#
# At iterate    5    f=  5.27124D-02    |proj g|=  4.69371D-01
#
# At iterate   10    f=  1.80486D-03    |proj g|=  3.74453D-03
#
# At iterate   15    f=  1.77064D-03    |proj g|=  4.12150D-03
#
# At iterate   20    f=  1.48216D-03    |proj g|=  2.37195D-02
#
# At iterate   25    f=  1.29523D-03    |proj g|=  1.27838D-04
#
# At iterate   30    f=  1.29477D-03    |proj g|=  4.29413D-04
#
# At iterate   35    f=  1.29069D-03    |proj g|=  5.85957D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     39     48      1     0     0   2.557D-04   1.290D-03
#   F =   1.2904207023448290E-003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.75855D-01    |proj g|=  8.43939D-01
#
# At iterate    5    f=  5.27124D-02    |proj g|=  4.69371D-01
#
# At iterate   10    f=  1.80486D-03    |proj g|=  3.74453D-03
#
# At iterate   15    f=  1.77064D-03    |proj g|=  4.12150D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   20    f=  1.48216D-03    |proj g|=  2.37195D-02
#
# At iterate   25    f=  1.29523D-03    |proj g|=  1.27838D-04
#
# At iterate   30    f=  1.29477D-03    |proj g|=  4.29413D-04
#
# At iterate   35    f=  1.29069D-03    |proj g|=  5.85957D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     39     48      1     0     0   2.557D-04   1.290D-03
#   F =   1.2904207023448290E-003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.75855D-01    |proj g|=  8.43939D-01
#
# At iterate    5    f=  5.27124D-02    |proj g|=  4.69371D-01
#
# At iterate   10    f=  1.80486D-03    |proj g|=  3.74453D-03
#
# At iterate   15    f=  1.77064D-03    |proj g|=  4.12150D-03
#
# At iterate   20    f=  1.48216D-03    |proj g|=  2.37195D-02
#
# At iterate   25    f=  1.29523D-03    |proj g|=  1.27838D-04
#
# At iterate   30    f=  1.29477D-03    |proj g|=  4.29413D-04
#
# At iterate   35    f=  1.29069D-03    |proj g|=  5.85957D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     39     48      1     0     0   2.557D-04   1.290D-03
#   F =   1.2904207023448290E-003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.68349D-01    |proj g|=  8.23593D-01
#
# At iterate    5    f=  8.07247D-02    |proj g|=  1.69979D-01
#
# At iterate   10    f= -1.59253D-03    |proj g|=  8.65514D-03
#
# At iterate   15    f= -1.72307D-03    |proj g|=  3.33569D-03
#
# At iterate   20    f= -2.03856D-03    |proj g|=  1.06704D-02
#
# At iterate   25    f= -2.29257D-03    |proj g|=  4.64335D-04
#
# At iterate   30    f= -2.29320D-03    |proj g|=  2.97790D-04
#
# At iterate   35    f= -2.29596D-03    |proj g|=  1.72397D-04
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     39     67      2     0     0   1.268D-04  -2.296D-03
#   F =  -2.2960042550048735E-003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.68349D-01    |proj g|=  8.23593D-01
#
# At iterate    5    f=  8.07247D-02    |proj g|=  1.69979D-01
#
# At iterate   10    f= -1.59253D-03    |proj g|=  8.65514D-03
#
# At iterate   15    f= -1.72307D-03    |proj g|=  3.33569D-03
#
# At iterate   20    f= -2.03856D-03    |proj g|=  1.06704D-02
#
# At iterate   25    f= -2.29257D-03    |proj g|=  4.64335D-04
#
# At iterate   30    f= -2.29320D-03    |proj g|=  2.97790D-04
#
# At iterate   35    f= -2.29596D-03    |proj g|=  1.72397D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     39     67      2     0     0   1.268D-04  -2.296D-03
#   F =  -2.2960042550048735E-003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.68349D-01    |proj g|=  8.23593D-01
#
# At iterate    5    f=  8.07247D-02    |proj g|=  1.69979D-01
#
# At iterate   10    f= -1.59253D-03    |proj g|=  8.65514D-03
#
# At iterate   15    f= -1.72307D-03    |proj g|=  3.33569D-03
#
# At iterate   20    f= -2.03856D-03    |proj g|=  1.06704D-02
#
# At iterate   25    f= -2.29257D-03    |proj g|=  4.64335D-04
#
# At iterate   30    f= -2.29320D-03    |proj g|=  2.97790D-04
#
# At iterate   35    f= -2.29596D-03    |proj g|=  1.72397D-04
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     39     67      2     0     0   1.268D-04  -2.296D-03
#   F =  -2.2960042550048735E-003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.59554D-01    |proj g|=  8.05304D-01
#
# At iterate    5    f=  8.47017D-02    |proj g|=  1.72247D-01
#
# At iterate   10    f= -5.56518D-03    |proj g|=  2.71026D-02
#
# At iterate   15    f= -5.89703D-03    |proj g|=  2.08348D-03
#
# At iterate   20    f= -6.22997D-03    |proj g|=  1.54863D-02
#
# At iterate   25    f= -6.51280D-03    |proj g|=  2.29205D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     29     35      1     0     0   6.860D-05  -6.514D-03
#   F =  -6.5143265239855225E-003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.59554D-01    |proj g|=  8.05304D-01
#
# At iterate    5    f=  8.47017D-02    |proj g|=  1.72247D-01
#
# At iterate   10    f= -5.56518D-03    |proj g|=  2.71026D-02
#
# At iterate   15    f= -5.89703D-03    |proj g|=  2.08348D-03
#
# At iterate   20    f= -6.22997D-03    |proj g|=  1.54863D-02
#
# At iterate   25    f= -6.51280D-03    |proj g|=  2.29205D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     29     35      1     0     0   6.860D-05  -6.514D-03
#   F =  -6.5143265239855225E-003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.59554D-01    |proj g|=  8.05304D-01
#
# At iterate    5    f=  8.47017D-02    |proj g|=  1.72247D-01
#
# At iterate   10    f= -5.56518D-03    |proj g|=  2.71026D-02
#
# At iterate   15    f= -5.89703D-03    |proj g|=  2.08348D-03
#
# At iterate   20    f= -6.22997D-03    |proj g|=  1.54863D-02
#
# At iterate   25    f= -6.51280D-03    |proj g|=  2.29205D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     29     35      1     0     0   6.860D-05  -6.514D-03
#   F =  -6.5143265239855225E-003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.59554D-01    |proj g|=  8.05304D-01
#
# At iterate    5    f=  8.47017D-02    |proj g|=  1.72247D-01
#
# At iterate   10    f= -5.56518D-03    |proj g|=  2.71026D-02
#
# At iterate   15    f= -5.89703D-03    |proj g|=  2.08348D-03
#
# At iterate   20    f= -6.22997D-03    |proj g|=  1.54863D-02
#
# At iterate   25    f= -6.51280D-03    |proj g|=  2.29205D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     29     35      1     0     0   6.860D-05  -6.514D-03
#   F =  -6.5143265239855225E-003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.63356D-01    |proj g|=  8.00945D-01
#
# At iterate    5    f=  8.10168D-02    |proj g|=  1.72660D-01
#
# At iterate   10    f= -8.60573D-03    |proj g|=  6.78775D-02
#
# At iterate   15    f= -9.98193D-03    |proj g|=  2.25834D-03
#
# At iterate   20    f= -1.00112D-02    |proj g|=  1.88577D-02
#
# At iterate   25    f= -1.04436D-02    |proj g|=  1.35153D-02
#
# At iterate   30    f= -1.06619D-02    |proj g|=  4.25093D-04
#
# At iterate   35    f= -1.06622D-02    |proj g|=  7.65266D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     35     39      1     0     0   7.653D-05  -1.066D-02
#   F =  -1.0662246106576501E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.63356D-01    |proj g|=  8.00945D-01
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  8.10168D-02    |proj g|=  1.72660D-01
#
# At iterate   10    f= -8.60573D-03    |proj g|=  6.78775D-02
#
# At iterate   15    f= -9.98193D-03    |proj g|=  2.25834D-03
#
# At iterate   20    f= -1.00112D-02    |proj g|=  1.88577D-02
#
# At iterate   25    f= -1.04436D-02    |proj g|=  1.35153D-02
#
# At iterate   30    f= -1.06619D-02    |proj g|=  4.25093D-04
#
# At iterate   35    f= -1.06622D-02    |proj g|=  7.65266D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     35     39      1     0     0   7.653D-05  -1.066D-02
#   F =  -1.0662246106576501E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# MSE: 0.4359079273966446
# MAE: 0.44472663391466294
# RMSE: 0.6602332371190083
# MAPE: 195.47990214162468%

# %% [markdown]
# ARIMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error, mean_absolute_error
import warnings
from dateutil.relativedelta import relativedelta

warnings.filterwarnings("ignore")
from pathlib import Path
import os

project_dir = Path(os.getcwd()).parent

# Define the path to the raw data folder relative to the project directory
data_dir = project_dir / 'data' / 'data_files' / 'processed_data'

# Load the data
data = pd.read_csv(data_dir / 'em_imputed_mq_stationary.csv')

# Convert the date column to datetime and set it as the index
data['date'] = pd.to_datetime(data['date'])
data.set_index('date', inplace=True)

# Function to standardize a single column
def z_score(x):
    return (x - x.mean()) / x.std()

normalized = data.copy()

normalized.loc[:, normalized.columns != 'date'] = normalized.loc[:, normalized.columns != 'date'].apply(z_score)

data = normalized

# Select the target variable (GDP)
target_variable = 'China: GDP: Current Prices:PoP GROWTHRATE'

# Check for missing values and handle them if necessary
data[target_variable] = data[target_variable].dropna()

# Split the data into train and test sets
train_data = data[data.index < '2018-06-30'][target_variable].dropna()
test_data = data[data.index >= '2018-06-30'][target_variable].dropna()

# Function to generate artificial testing vintages
def generate_artificial_vintages(data, test_start_date, target_variable):
    test_dates = data[data.index >= test_start_date].index
    vintages = []
    
    for test_date in test_dates:
        train_end_date = test_date - relativedelta(months=1)
        train_data = data[data.index <= train_end_date][target_variable]
        test_value = data.loc[test_date, target_variable]
        vintages.append((train_data, test_date, test_value))
    
    return vintages

# Generate artificial testing vintages
vintages = generate_artificial_vintages(data, '2018-06-30', target_variable)

# Initialize lists to store results
forecasts = []
actuals = []
forecast_dates = []
confidence_intervals = []

# Iterate through vintages
for train_data, test_date, actual_value in vintages:
    # Check for and remove any inf or nan values
    train_data = train_data[np.isfinite(train_data)]
    
    if len(train_data) == 0:
        print(f"Warning: No valid data for {test_date}")
        continue

    try:
        # Perform ADF test
        result = adfuller(train_data)

        # If the series is not stationary, difference the training data
        if result[1] > 0.05:
            train_data = train_data.diff().dropna()
            d = 1
        else:
            d = 0

        # Fit the ARIMA model on the training data
        # Define the order (p, d, q) for ARIMA model
        p = 3 # order of the autoregressive part
        q = 1 # order of the moving average part

        # Fit the ARIMA model
        arima_model = ARIMA(train_data, order=(p, d, q))
        arima_result = arima_model.fit()

        # Forecast for the test date
        forecast = arima_result.get_forecast(steps=1)
        mean_forecast = forecast.predicted_mean[0]
        conf_int = forecast.conf_int()
        
        forecasts.append(mean_forecast)
        actuals.append(actual_value)
        forecast_dates.append(test_date)
        confidence_intervals.append(conf_int)
    except Exception as e:
        print(f"Error forecasting for {test_date}: {str(e)}")

# Convert forecasts and actuals to numpy arrays, dropping NaN values
forecasts = np.array(forecasts)
actuals = np.array(actuals)
forecast_dates = pd.to_datetime(forecast_dates)
confidence_intervals = np.array(confidence_intervals).squeeze()

# Drop NaN values from actuals and corresponding forecasts, dates, and confidence intervals
mask = ~np.isnan(actuals)
actuals = actuals[mask]
forecasts = forecasts[mask]
forecast_dates = forecast_dates[mask]
confidence_intervals = confidence_intervals[mask]

# Plot the forecast against actual test data for the test period only
plt.figure(figsize=(10, 6))
plt.plot(test_data.index, test_data, label='Actual Test Data')
plt.plot(forecast_dates, forecasts, label='Forecast')
plt.fill_between(forecast_dates, confidence_intervals[:, 0], confidence_intervals[:, 1], color='gray', alpha=0.2, label='95% Confidence Interval')
plt.title('ARIMA Forecast vs Actual (Test Period)')
plt.legend()
plt.show()

# Evaluate the model on the test data
mse = mean_squared_error(actuals, forecasts)
mae = mean_absolute_error(actuals, forecasts)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((actuals - forecasts) / actuals)) * 100

print(f'MSE: {mse}')
print(f'MAE: {mae}')
print(f'RMSE: {rmse}')
print(f'MAPE: {mape}%')
# Out:
# MSE: 0.5077688728199273
# MAE: 0.5056565399935495
# RMSE: 0.7125790291749592
# MAPE: 165.73634896507465%
